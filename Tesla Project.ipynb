# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Tesla.csv - Tesla.csv.csv')

# %%
df.head(10)
# Out:
#         Date       Open       High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.000000  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.420000  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.920000  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.100000  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.000000  15.830000  16.110001   6866900  16.110001
# 5   7/7/2010  16.400000  16.629999  14.980000  15.800000   6921700  15.800000
# 6   7/8/2010  16.139999  17.520000  15.570000  17.459999   7711400  17.459999
# 7   7/9/2010  17.580000  17.900000  16.549999  17.400000   4050600  17.400000
# 8  7/12/2010  17.950001  18.070000  17.000000  17.049999   2202500  17.049999
# 9  7/13/2010  17.389999  18.639999  16.900000  18.139999   2680100  18.139999

# %%
df['High']
# Out:
# 0        25.000000
# 1        30.420000
# 2        25.920000
# 3        23.100000
# 4        20.000000
#            ...
# 1687    246.850006
# 1688    258.119995
# 1689    261.000000
# 1690    265.750000
# 1691    265.329987
# Name: High, Length: 1692, dtype: float64

# %%
df['High'].max()
# Out:
# 291.420013

# %%
df['High'].min()
# Out:
# 16.629998999999998

# %%
df.std()
# Out:
# Open         9.430992e+01
# High         9.569491e+01
# Low          9.285523e+01
# Close        9.431319e+01
# Volume       4.295971e+06
# Adj Close    9.431319e+01
# dtype: float64

# %%
#Return for each day

# %%
df['Close'].pct_change()
# Out:
# 0            NaN
# 1      -0.002511
# 2      -0.078473
# 3      -0.125683
# 4      -0.160937
#           ...
# 1687    0.010177
# 1688    0.048056
# 1689   -0.008798
# 1690    0.024714
# 1691   -0.002099
# Name: Close, Length: 1692, dtype: float64

# %%
sns.pairplot(df[1:])

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
tester = df['Close'].pct_change()

# %%
tester
# Out:
# 0            NaN
# 1      -0.002511
# 2      -0.078473
# 3      -0.125683
# 4      -0.160937
#           ...
# 1687    0.010177
# 1688    0.048056
# 1689   -0.008798
# 1690    0.024714
# 1691   -0.002099
# Name: Close, Length: 1692, dtype: float64

# %%
sns.set_style('whitegrid')
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
sns.distplot(tester, color='blue', bins=30)

# %%
df['Close'].plot(label='Tesla',figsize=(12,4))

# %%
df['Volume'].max()
# Out:
# 37163900

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Tesla')
# Out:
# Text(0.5, 1, 'Tesla')

# %%
plt.figure(figsize=(13,5))
plt.plot(df['Volume'], label = 'TSLA')
plt.title('Tesla Volume Over The Years')
plt.xlabel('Year')
plt.ylabel('Volume')
plt.legend(loc='upper left')
plt.show()

# %%
SMA100 = pd.DataFrame()
SMA100['Adj Close'] = df['Adj Close'].rolling(window=100).mean()
SMA100
# Out:
#       Adj Close
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1687   222.2524
# 1688   222.8414
# 1689   223.3631
# 1690   223.9926
# 1691   224.6067
#
# [1692 rows x 1 columns]

# %%
plt.figure(figsize=(12,4))
plt.plot(df['Adj Close'], label = 'Adj Close')
plt.plot(SMA100['Adj Close'], label = 'SMA100')
plt.title('Closing Price Throughout The Years')
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.legend(loc='upper left')
plt.show()
